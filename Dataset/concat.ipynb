# %%
import pandas as pd

# %%
a=pd.read_csv('whiskey_images_links.csv',sep="$")
b=pd.read_csv('whiskey_w_tags_norm.csv',sep="$")

# %%
b
# Out:
#                                                 Whiskey  Meta Critic  STDEV  \
# 0     Macallan 10yo Full Proof 57% 1980 (OB, Giovine...         9.57   0.24
# 1                                   Ledaig 42yo Dusgadh         9.48   0.19
# 2     Laphroaig 27yo 57.4% 1980-2007 (OB, 5 Oloroso ...         9.42   0.23
# 3                                      Glenfarclas 40yo         9.29   0.26
# 4                                        Glengoyne 25yo         9.24   0.22
# ...                                                 ...          ...    ...
# 1195                               Tomintoul Peaty Tang         7.99   0.53
# 1196                      Santis Edition Dreifaltigkeit         7.97   1.34
# 1197                     McClelland's Islay Single Malt         7.78   0.70
# 1198  Santis Edition Dreifaltigkeit / Cask Strength ...         7.19   1.76
# 1199                        Santis Cask Strength Peated         6.46   1.89
#
# ...

# %%
total=pd.concat([b,a[['images','links']]],axis=1)

# %%
total.to_csv('total_df.csv',sep="$",index=False)
